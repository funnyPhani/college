# %%
import requests
from bs4 import BeautifulSoup
for i in range(1,5):
    url='http://quotes.toscrape.com/page/'+str(i)
    req=requests.get(url).content
    soup=BeautifulSoup(req,'html.parser')
    #print(soup)
    quotes=soup.find_all('span',class_='text')
    print('PAGEID :',i)
    print()
    for quote in quotes:
        print(quote.text)
    print()
# Out:
# PAGEID : 1
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”
#
# PAGEID : 2
#
# ...

# %%
url='https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page='+str(i)
req=requests.get(url).content
soup=BeautifulSoup(req,'html.parser')
#print(soup)
quotes=soup.find('div',class_='_3wU53n')
print(quotes.text)
# Out:
# Infinix Hot 10 (Obsidian Black, 128 GB)

# %%
import requests
from bs4 import BeautifulSoup
for i in range(1,3):
    #url='http://quotes.toscrape.com/page/'+str(i)
    url='https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page='+str(i)
    req=requests.get(url).content
    soup=BeautifulSoup(req,'html.parser')
    #print(soup)
    quotes=soup.find_all('div',class_='_3wU53n')
    prices=soup.find_all('div',class_='_1vC4OE _2rQ-NK')
    rating=soup.find_all('div',class_='hGSR34')
    
    print('PAGEID :',i)
    print()
    for quote,price in zip(quotes,prices):
        print(quote.text,'-'*10,price.text)
    
    print()
# Out:
# PAGEID : 1
#
# Realme C11 (Rich Grey, 32 GB) ---------- ₹6,499
# Realme C11 (Rich Green, 32 GB) ---------- ₹6,499
# Realme C12 (Power Blue, 32 GB) ---------- ₹7,999
# Realme C12 (Power Silver, 32 GB) ---------- ₹7,999
# Apple iPhone SE (Black, 64 GB) ---------- ₹27,999
# Realme C15 (Power Silver, 32 GB) ---------- ₹8,499
# Realme C15 (Power Blue, 32 GB) ---------- ₹8,499
# Realme C15 (Power Blue, 64 GB) ---------- ₹9,499
# Realme C15 (Power Silver, 64 GB) ---------- ₹9,499
# Redmi 9i (Midnight Black, 64 GB) ---------- ₹8,299
# Apple iPhone XR (White, 64 GB) ---------- ₹37,999
# POCO M2 (Pitch Black, 64 GB) ---------- ₹10,499
# Apple iPhone XR (Black, 64 GB) ---------- ₹37,999
# Redmi 9i (Nature Green, 64 GB) ---------- ₹8,299
# POCO M2 (Slate Blue, 128 GB) ---------- ₹11,499
# POCO X3 (Cobalt Blue, 128 GB) ---------- ₹18,499
# POCO X3 (Shadow Gray, 128 GB) ---------- ₹18,499
# POCO C3 (Matte Black, 32 GB) ---------- ₹7,499
# POCO M2 (Slate Blue, 64 GB) ---------- ₹10,499
# ...

# %%
quo=[]
pri=[]
rat=[]
import requests
from bs4 import BeautifulSoup
for i in range(1,8):
    #url='http://quotes.toscrape.com/page/'+str(i)
    #url='https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page='+str(i)
    url='https://www.flipkart.com/search?q=apple+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_5_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=apple+mobiles%7CMobiles&requestId=dd075506-2050-4b7b-9380-0b0461cf1bd3&as-backfill=on'+str(i)
    req=requests.get(url).content
    soup=BeautifulSoup(req,'html.parser')
    #print(soup)
    quotes=soup.find_all('div',class_='_3wU53n')
    prices=soup.find_all('div',class_='_1vC4OE _2rQ-NK')
    rating=soup.find_all('div',class_='hGSR34')
    
    #print('PAGEID :',i)
    #print()
    for quote in quotes:
        quo.append(quote.text)
    for price in prices:
        pri.append(price.text)
    for rate in rating:
        rat.append(rate.text)
    
    #print()

# %%
import pandas as pd
pd.set_option('display.max_rows',None)

# %%
df=pd.DataFrame(zip(quo,pri,rat),columns=['mobile name','price','rating'])

# %%
df.head()
# Out:
#                       mobile name    price rating
# 0  Apple iPhone SE (Black, 64 GB)  ₹34,999    4.6
# 1  Apple iPhone SE (White, 64 GB)  ₹34,999    4.6
# 2  Apple iPhone XR (Black, 64 GB)  ₹44,999    4.6
# 3  Apple iPhone XR (White, 64 GB)  ₹44,999    4.6
# 4    Apple iPhone SE (Red, 64 GB)  ₹34,999    4.6

# %%
df.sort_values('price',).reset_index(drop=True)
# Out:
#                                            mobile name      price rating
# 0               Apple iPhone 12 Pro (Graphite, 128 GB)  ₹1,19,900    4.6
# 1           Apple iPhone 12 Pro (Pacific Blue, 128 GB)  ₹1,19,900    4.7
# 2           Apple iPhone 12 Pro (Pacific Blue, 128 GB)  ₹1,19,900      4
# 3           Apple iPhone 12 Pro (Pacific Blue, 128 GB)  ₹1,19,900    4.6
# 4               Apple iPhone 12 Pro (Graphite, 128 GB)  ₹1,19,900      5
# 5               Apple iPhone 12 Pro (Graphite, 128 GB)  ₹1,19,900    4.6
# 6           Apple iPhone 12 Pro (Pacific Blue, 128 GB)  ₹1,19,900    4.6
# 7               Apple iPhone 12 Pro (Graphite, 128 GB)  ₹1,19,900    4.6
# 8           Apple iPhone 12 Pro (Pacific Blue, 128 GB)  ₹1,19,900      5
# 9               Apple iPhone 12 Pro (Graphite, 128 GB)  ₹1,19,900    4.6
# 10          Apple iPhone 12 Pro (Pacific Blue, 128 GB)  ₹1,19,900    4.6
# 11              Apple iPhone 12 Pro (Graphite, 128 GB)  ₹1,19,900    4.6
# ...

# %%
plt.figure(figsize=(14,4))

ax=sns.countplot(df.rating,hue=df.price)
for p in ax.patches:
    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))
plt.legend(loc='upper left')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
sns.countplot(df.rating)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(df['mobile name'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
o=plt.style.use('fivethirtyeight')

# %%
plt.figure(figsize=(15,4))
sns.scatterplot(df.price,df.rating,color='red')
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(15,4))
sns.scatterplot(df.price,df.rating,color='red')
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(15,4))
sns.countplot(df.price,hue=df.rating);
plt.xticks(rotation=45);
plt.legend(loc='upper right')

# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/laxmimerit/Amazon-Musical-Reviews-Rating-Dataset/master/Musical_instruments_reviews.csv')

# %%
df1
# Out:
#            reviewerID        asin  \
# 0      A2IBPI20UZIR0U  1384719342
# 1      A14VAT5EAX3D9S  1384719342
# 2      A195EZSQDW3E21  1384719342
# 3      A2C00NNG1ZQQG2  1384719342
# 4       A94QU4C90B1AX  1384719342
# ...               ...         ...
# 10256  A14B2YH83ZXMPP  B00JBIVXGC
# 10257   A1RPTVW5VEOSI  B00JBIVXGC
# 10258   AWCJ12KBO5VII  B00JBIVXGC
# 10259  A2Z7S8B5U4PAKJ  B00JBIVXGC
# 10260  A2WA8TDCTGUADI  B00JBIVXGC
#
#                                            reviewerName   helpful  \
# 0      cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                                  Jake  [13, 14]
# 2                         Rick Bennette "Rick Bennette"    [1, 1]
# 3                             RustyBill "Sunday Rocker"    [0, 0]
# 4                                         SEAN MASLANKA    [0, 0]
# ...                                                 ...       ...
# 10256                                   Lonnie M. Adams    [0, 0]
# ...

# %%
df1.shape
# Out:
# (10261, 9)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='black',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(df1['summary'])

# %%
data={'name':['phani','kiran','teja','vani','srinu']}
dd=pd.DataFrame(data)

# %%
dd
# Out:
#     name
# 0  phani
# 1  kiran
# 2   teja
# 3   vani
# 4  srinu

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=3,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(dd['name'])

# %%
title=[]
price=[]
rating=[]
review=[]

import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
#url='https://www.flipkart.com/search?q=mobiles'
for i in range(1,2):
    url='https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page='+str(i)
    req=requests.get(url).content
    soup=BeautifulSoup(req,'html.parser')
    #print(soup)

    titles=soup.find_all('div',class_='_3wU53n')
    prices=soup.find_all('div',class_='_1vC4OE _2rQ-NK')
    ratings=soup.find_all('div',class_='hGSR34')
    reviews=soup.find_all('span',class_='_38sUEc')


    # for tis,prs,ras,res in zip(titles,prices,rating,reviews):
    #     title.append(tis.text)
    #     price.append(prs.text)
    #     rating.append(ras.text)
    #     review.append(res.text)

    for ti in titles:
        title.append(ti.text)
    for pr in prices:
        price.append(pr.text)
    for ra in ratings:
        rating.append(ra.text)
    for rev in reviews:
        review.append(rev.text)

# %%
df=pd.DataFrame(zip(title,price,rating,review),columns=['Title','Prices','Ratings','Reviews'])

# %%
df.head()
# Out:
#                               Title   Prices Ratings  \
# 0    Realme C12 (Power Blue, 32 GB)   ₹8,999     4.5
# 1  Realme C12 (Power Silver, 32 GB)   ₹8,999     4.5
# 2  Redmi 9i (Midnight Black, 64 GB)   ₹8,299     4.4
# 3    Realme C15 (Power Blue, 64 GB)  ₹10,499     4.5
# 4    Realme C15 (Power Blue, 32 GB)   ₹9,499     4.4
#
#                           Reviews
# 0  93,825 Ratings & 5,203 Reviews
# 1  93,825 Ratings & 5,203 Reviews
# 2  37,349 Ratings & 1,822 Reviews
# 3  47,379 Ratings & 2,544 Reviews
# 4    11,477 Ratings & 667 Reviews

# %%
df.sort_values('Prices').reset_index(drop=True).head()
# Out:
#                                    Title   Prices Ratings  \
# 0  Realme Narzo 20 (Victory Blue, 64 GB)  ₹10,499     4.4
# 1  Realme Narzo 20 (Glory Silver, 64 GB)  ₹10,499     4.4
# 2         Realme C15 (Power Blue, 64 GB)  ₹10,499     4.5
# 3            POCO M2 (Slate Blue, 64 GB)  ₹10,499     4.3
# 4       Realme C15 (Power Silver, 64 GB)  ₹10,499     4.5
#
#                           Reviews
# 0  79,773 Ratings & 6,058 Reviews
# 1  79,773 Ratings & 6,058 Reviews
# 2  47,379 Ratings & 2,544 Reviews
# 3  84,668 Ratings & 6,752 Reviews
# 4  47,379 Ratings & 2,544 Reviews

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(14,4))

ax=sns.countplot(df.Ratings,hue=df.Prices)
#for p in ax.patches:
#    ax.annotate('{}'.format(p.get_height()), (p.get_x(), p.get_height()+1))
#plt.legend(loc='upper right')

# %% [markdown]
# # Stackoverflow

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


# importing Libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
import seaborn as sns

# In[10]:


#url ='https://stackoverflow.com/questions/tagged/python?tab=Frequent'
# link = requests.get(url).text


# In[12]:


# soup = BeautifulSoup(link,'html')
# print(soup.prettify())


# In[13]:


# soup.title.string


# In[20]:


# data = soup.find_all('div',id='questions') # Extracting questions,summary and tags

questions=[]
summary =[]
tag_cloud=[]
no_answers =[]
views =[]
search=input('enter the program to get the queries :')
pages=int(input('enter no.of pages to scrape :'))
for i in range(1,pages):
    #url ='https://stackoverflow.com/questions/tagged/python?tab=Frequent'
    
    url='https://stackoverflow.com/questions/tagged/{}?tab=frequent&page={}&pagesize=15'.format(search,i)
    link = requests.get(url).text
    soup = BeautifulSoup(link,'html')
    #print(soup.prettify())
    data = soup.find_all('div',id='questions') # Extracting questions,summary and tags

    for i in data:
        qtn=i.findAll('h3')
        for qn in qtn:
            questions.append(qn.text) # Questions

        summ = i.find_all('div',class_='excerpt')
        for sum_data in summ:
            summary.append(sum_data.text) # Summary

        tag_data = i.find_all('div',class_='tags')
        for tag in tag_data:
            tags = tag.text
            tag_cloud.append(tags.split()) # Tags
        
    # For getting No.of Answers
    data = soup.find_all('div',class_='status')
    for ans in data:
        answers=ans.findAll('strong')
        for ant in answers:
            no_answers.append(ant.text)

    # for getting No.of Views
    data = soup.find_all('div','views')
    for view in data:
        views.append(view.get('title'))


# Creating DataFrame

stack = pd.DataFrame()
stack['Questions'] = questions
stack['Summary'] = summary
stack['Tags'] = tag_cloud
stack['Views'] = views
stack['No.of Answers'] = no_answers

# Exporting Data to Excel file
stack.to_excel('stack_question.xlsx')
#stack.to_csv('stackdata.csv',index=False)
display(stack.head())

# In[ ]:


import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(15,4))
sns.countplot(stack['No.of Answers'])
plt.xticks(rotation=45)
plt.show()
# Out:
# enter the program to get the queries :python
# enter no.of pages to scrape :15
#                                            Questions  \
# 0      How to make good reproducible pandas examples
# 1    How to test multiple variables against a value?
# 2  Asking the user for input until they give a va...
# 3                       Understanding slice notation
# 4  List of lists changes reflected across sublist...
#
#                                              Summary  \
# 0  \r\n            Having spent a decent amount o...
# 1  \r\n            I'm trying to make a function ...
# 2  \r\n            I am writing a program that ac...
# 3  \r\n            I need a good explanation (ref...
# 4  \r\n            I needed to create a list of l...
#
#                                                 Tags            Views  \
# 0                                   [python, pandas]     25,278 views
# 1  [python, if-statement, comparison, match, bool...    282,293 views
# ...

# %%
import numpy as np

# %%
np.random.rand(4)
# Out:
# array([0.87838585, 0.73909192, 0.22864168, 0.73455273])

# %%
a=5
b=4
x='{}/{}'.format(a,b)
x
# Out:
# '5/4'
